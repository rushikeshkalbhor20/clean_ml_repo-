# %%
# End to End Toy Project | Day 13 | 100 Days of Machine Learning

# Intro
# Plan of attack
# Preprocessing
# EDA
# Scatterplot example
# Feature Selection
# Extracting Input and Output columns
# Train Test Split
# Evaluating the model
# Accuracy Score
# Exporting the Model
# Deploying the Model on Cloud

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:/Users/HP/Documents/Brainworks_recordings/Python Lectures/Pandas/CSV_Files/csv_file_End_to_End_Toy_Project_Day_13/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.shape
# Out:
# (100, 3)

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
# 1. Extract input and output cols
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
y.shape
# Out:
# (100,)

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
# Train test split

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 23   4.7   87.0
# 25   5.0   91.0
# 20   6.6  120.0
# 3    7.4  132.0
# 16   5.2  224.0
# ..   ...    ...
# 53   8.3  168.0
# 10   6.0   45.0
# 4    5.8  142.0
# 60   6.9  139.0
# 65   8.1  166.0
#
# [90 rows x 2 columns]

# %%
X_test
# Out:
#     cgpa     iq
# 37   8.1  149.0
# 7    5.0   63.0
# 56   6.1   65.0
# 80   4.9  196.0
# 12   5.4  139.0
# 35   6.8   90.0
# 30   7.6  128.0
# 9    5.1   66.0
# 96   4.4   42.0
# 76   4.9  155.0

# %%
y_train
# Out:
# 23    0
# 25    0
# 20    1
# 3     1
# 16    0
#      ..
# 53    1
# 10    1
# 4     0
# 60    1
# 65    1
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 37    1
# 7     0
# 56    0
# 80    0
# 12    0
# 35    1
# 30    1
# 9     0
# 96    0
# 76    0
# Name: placement, dtype: int64

# %%
# Scale the values

from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-1.15935897, -0.99510116],
#        [-0.89363153, -0.89081109],
#        [ 0.52358147, -0.13470802],
#        [ 1.23218797,  0.17816222],
#        [-0.71647991,  2.57683402],
#        [-0.27360084,  0.17816222],
#        [ 0.08070241,  0.80390269],
#        [-0.18502503,  1.06462788],
#        [ 0.34642985, -0.2389981 ],
#        [ 1.14361216, -1.02117368],
#        [ 0.78930891, -0.76044849],
#        [-1.24793478,  0.54317749],
#        [-1.07078316,  0.98641032],
#        [ 1.58649122, -0.29114314],
#        [ 0.25785403,  0.07387214],
#        [ 0.87788472,  1.92502103],
#        [-1.42508641,  0.62139505],
#        [ 0.87788472, -1.59476912],
#        [-0.71647991, -0.91688361],
#        [ 0.25785403, -0.57794085],
#        [ 0.16927822, -0.31721566],
#        [-2.22226873,  2.8114867 ],
#        [-1.51366222,  1.95109355],
#        [ 0.96646054, -2.01192943],
#        [-1.77938966, -1.3079714 ],
#        [-0.00787341, -0.03041794],
#        [-0.00787341, -0.60401337],
# ...

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 1.85221866,  0.62139505],
#        [-0.89363153, -1.62084163],
#        [ 0.08070241, -1.5686966 ],
#        [-0.98220735,  1.84680347],
#        [-0.53932828,  0.36066985],
#        [ 0.7007331 , -0.91688361],
#        [ 1.4093396 ,  0.07387214],
#        [-0.80505572, -1.54262408],
#        [-1.42508641, -2.16836455],
#        [-0.98220735,  0.77783017]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
ypred = clf.predict(X_test)

# %%
y_test
# Out:
# 37    1
# 7     0
# 56    0
# 80    0
# 12    0
# 35    1
# 30    1
# 9     0
# 96    0
# 76    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,ypred)
# Out:
# 0.9

# %%
pip install mlxtend
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 11.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
