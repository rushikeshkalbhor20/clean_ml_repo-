# %% [raw]
# classification-metrics-multi-iris1-Day75

# %% [raw]
# Accuracy and Confusion Matrix | Type 1 and Type 2 Errors | Classification Metrics Part 1

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/HP/Desktop/100 Days Machine learning/Csv.files/train_Iris.csv')

# %%
df.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0   59            6.6           2.9            4.6           1.3
# 1   98            6.2           2.9            4.3           1.3
# 2  130            7.2           3.0            5.8           1.6
# 3  115            5.8           2.8            5.1           2.4
# 4  147            6.3           2.5            5.0           1.9
#
#            Species
# 0  Iris-versicolor
# 1  Iris-versicolor
# 2   Iris-virginica
# 3   Iris-virginica
# 4   Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             120 non-null    int64
#  1   SepalLengthCm  120 non-null    float64
#  2   SepalWidthCm   120 non-null    float64
#  3   PetalLengthCm  120 non-null    float64
#  4   PetalWidthCm   120 non-null    float64
#  5   Species        120 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 5.8+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['Species'] = encoder.fit_transform(df['Species'])

# %%
df.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 89    31            4.8           3.1            1.6           0.2        0
# 16    53            6.9           3.1            4.9           1.5        1
# 73    29            5.2           3.4            1.4           0.2        0
# 108  116            6.4           3.2            5.3           2.3        2
# 67    81            5.5           2.4            3.8           1.1        1
# 80    19            5.7           3.8            1.7           0.3        0
# 71   135            6.1           2.6            5.6           1.4        2
# 32   107            4.9           2.5            4.5           1.7        2
# 61     8            5.0           3.4            1.5           0.2        0
# 0     59            6.6           2.9            4.6           1.3        1

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,0:-1],df.iloc[:,-1],test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
clf1 = LogisticRegression()
clf2 = DecisionTreeClassifier()

# %%
clf1.fit(X_train,y_train)
clf2.fit(X_train,y_train)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# DecisionTreeClassifier()

# %%
y_pred1 = clf1.predict(X_test)
y_pred2 = clf2.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
print("Accuracy of Logistic Regression",accuracy_score(y_test,y_pred1))
print("Accuracy of Decision Trees",accuracy_score(y_test,y_pred2))
# Out:
# Accuracy of Logistic Regression 1.0
# Accuracy of Decision Trees 0.9583333333333334

# %%
print("Logistic Regression Confusion Matrix\n")
pd.DataFrame(confusion_matrix(y_test,y_pred1),columns=list(range(0,3)))
# Out:
# Logistic Regression Confusion Matrix
#     0  1   2
# 0  10  0   0
# 1   0  4   0
# 2   0  0  10

# %%
print("Decision Tree Confusion Matrix\n")
pd.DataFrame(confusion_matrix(y_test,y_pred2),columns=list(range(0,3)))
# Out:
# Decision Tree Confusion Matrix
#     0  1  2
# 0  10  0  0
# 1   0  4  0
# 2   0  1  9

# %%
result = pd.DataFrame()
result['Actual Label'] = y_test
result['Logistic Regression Prediction'] = y_pred1
result['Decision Tree Prediction'] = y_pred2
result.sample(10)
# Out:
#      Actual Label  Logistic Regression Prediction  Decision Tree Prediction
# 56              0                               0                         0
# 112             0                               0                         0
# 106             2                               2                         1
# 99              2                               2                         2
# 81              0                               0                         0
# 2               2                               2                         2
# 17              1                               1                         1
# 48              2                               2                         2
# 103             2                               2                         2
# 46              0                               0                         0

# %%
from sklearn.metrics import precision_score,recall_score,f1_score
precision_score(y_test,y_pred1,average=None)
# Out:
# array([1., 1., 1.])

# %%
print('Logistic Regression Prediction',recall_score(y_test,y_pred1,average=None))
# Out:
# Logistic Regression Prediction [1. 1. 1.]

# %%
print('Logistic Regression Prediction',f1_score(y_test,y_pred1,average=None))
# Out:
# Logistic Regression Prediction [1. 1. 1.]

# %%
print('Desission Tree Prediction',recall_score(y_test,y_pred2,average=None))
# Out:
# Desission Tree Prediction [1.  1.  0.9]

# %%
print('Desission Tree Prediction',f1_score(y_test,y_pred2,average=None))
# Out:
# Desission Tree Prediction [1.         0.88888889 0.94736842]

# %%
print('Desission Tree Prediction',precision_score(y_test,y_pred2,average=None))
# Out:
# array([1. , 0.8, 1. ])

# %%
print('Desission Tree Prediction',precision_score(y_test,y_pred1,average=None))
# Out:
# Logistic Regression Prediction [1. 1. 1.]
