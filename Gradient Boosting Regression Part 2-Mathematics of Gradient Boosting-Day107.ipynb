# %% [raw]
# Gradient Boosting Regression Part 2 | Mathematics of Gradient Boosting

# %% [raw]
# Gradient Boosting Regression Part 2-Mathematics of Gradient Boosting-Day107

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/HP/Desktop/100 Days Machine learning/Csv.files/50_Startups.csv')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df = df.iloc[:,[0,1,2,4]]

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit
# 0  165349.20       136897.80        471784.10  192261.83
# 1  162597.70       151377.59        443898.53  191792.06
# 2  153441.51       101145.55        407934.54  191050.39
# 3  144372.41       118671.85        383199.62  182901.99
# 4  142107.34        91391.77        366168.42  166187.94

# %%
df = df.iloc[[0,11,36]]
df = round(df/100)

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit
# 0      1653.0          1369.0           4718.0  1923.0
# 11     1007.0           918.0           2497.0  1443.0
# 36      287.0          1271.0           2011.0   907.0

# %%
df['f0(x)'] = df['Profit'].mean()

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit        f0(x)
# 0      1653.0          1369.0           4718.0  1923.0  1424.333333
# 11     1007.0           918.0           2497.0  1443.0  1424.333333
# 36      287.0          1271.0           2011.0   907.0  1424.333333

# %%
df['ri1'] = df['Profit'] - df['f0(x)']

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit        f0(x)  \
# 0      1653.0          1369.0           4718.0  1923.0  1424.333333
# 11     1007.0           918.0           2497.0  1443.0  1424.333333
# 36      287.0          1271.0           2011.0   907.0  1424.333333
#
#            ri1
# 0   498.666667
# 11   18.666667
# 36 -517.333333

# %%
from sklearn.tree import DecisionTreeRegressor
dt1 = DecisionTreeRegressor(max_depth=1)

# %%
dt1.fit(df.iloc[:,0:3].values, df['ri1'].values)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
from sklearn.tree import plot_tree
plot_tree(dt1)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 647.0\nsquared_error = 172216.889\nsamples = 3\nvalue = 0.0'),
#  Text(0.25, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = -517.333'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'squared_error = 57600.0\nsamples = 2\nvalue = 258.667'),
#  Text(0.625, 0.5, '  False')]
